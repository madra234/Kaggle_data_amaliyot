# %% [markdown]
# <a href="https://colab.research.google.com/github/madra234/Kaggle_data_amaliyot/blob/main/Malumotlarga_ishlov_berish.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 3-modul ma'lumotlarga ishlov berish
# # Multi indekslash

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# - Harerchical indexing (irarxik indekslash)

# %%
data = pd.Series(np.random.randn(9),
                 index=['a', 'a', 'a', 'b', 'b', 'c', 'c', 'd', 'd'])
data.index
# Out:
# Index(['a', 'a', 'a', 'b', 'b', 'c', 'c', 'd', 'd'], dtype='object')

# %%
data1 = pd.Series(np.random.randn(9),
                  index=[['a', 'a', 'a', 'b', 'b', 'c', 'c', 'd', 'd'], [1, 2, 3, 1, 3, 1, 2, 2, 3]])
data1.index
# Out:
# MultiIndex([('a', 1),
#             ('a', 2),
#             ('a', 3),
#             ('b', 1),
#             ('b', 3),
#             ('c', 1),
#             ('c', 2),
#             ('d', 2),
#             ('d', 3)],
#            )

# %% [markdown]
# - Malumotlarni ajratib olish

# %%
data1['a'] # Multi index ma'lumotlarida malumotlarni kesib olish
# Out:
# 1   -1.439374
# 2    2.581946
# 3   -0.266428
# dtype: float64

# %%
data1.loc[:, 2]
# Out:
# a    2.581946
# c    0.256345
# d   -2.045894
# dtype: float64

# %%
data1.loc[['b', 'd']]
# Out:
# b  1   -0.250322
#    3    1.088075
# d  2   -2.045894
#    3    1.387578
# dtype: float64

# %%
data1.loc[:, 1]
# Out:
# a   -1.439374
# b   -0.250322
# c    0.717389
# dtype: float64

# %%
data1
# Out:
# a  1   -1.439374
#    2    2.581946
#    3   -0.266428
# b  1   -0.250322
#    3    1.088075
# c  1    0.717389
#    2    0.256345
# d  2   -2.045894
#    3    1.387578
# dtype: float64

# %%
data1.loc[:, 3]
# Out:
# a   -0.266428
# b    1.088075
# d    1.387578
# dtype: float64

# %% [markdown]
# - unstack()- metodi

# %%
data1
# Out:
# a  1   -1.439374
#    2    2.581946
#    3   -0.266428
# b  1   -0.250322
#    3    1.088075
# c  1    0.717389
#    2    0.256345
# d  2   -2.045894
#    3    1.387578
# dtype: float64

# %%
data1.unstack() # sochilgan elementlarni df ko'rinishiga keltirib beradi
# Out:
#           1         2         3
# a -1.439374  2.581946 -0.266428
# b -0.250322       NaN  1.088075
# c  0.717389  0.256345       NaN
# d       NaN -2.045894  1.387578

# %%
data1.unstack().stack() # stack() metodi orginal holatga qaytaradi
# Out:
# a  1   -1.439374
#    2    2.581946
#    3   -0.266428
# b  1   -0.250322
#    3    1.088075
# c  1    0.717389
#    2    0.256345
# d  2   -2.045894
#    3    1.387578
# dtype: float64

# %% [markdown]
# Dunyo shaharlarinning havo va suv ustida amallar bajarish

# %%
# !git clone https://github.com/MansurCompAI/Practicum_Datasets
# Out:
# Cloning into 'Practicum_Datasets'...
# remote: Enumerating objects: 60, done.
# remote: Counting objects: 100% (60/60), done.
# remote: Compressing objects: 100% (55/55), done.
# remote: Total 60 (delta 17), reused 16 (delta 1), pack-reused 0 (from 0)
# Receiving objects: 100% (60/60), 20.24 MiB | 16.57 MiB/s, done.
# Resolving deltas: 100% (17/17), done.

# %%
df = pd.read_csv('/content/Practicum_Datasets/world_cities_air_water_quality.csv')
df.head()
# Out:
#                City                 "Region"                    "Country"  \
# 0     New York City               "New York"   "United States of America"
# 1  Washington, D.C.   "District of Columbia"   "United States of America"
# 2     San Francisco             "California"   "United States of America"
# 3            Berlin                       ""                    "Germany"
# 4       Los Angeles             "California"   "United States of America"
#
#     "AirQuality"   "WaterPollution"
# 0      46.816038          49.504950
# 1      66.129032          49.107143
# 2      60.514019          43.000000
# 3      62.364130          28.612717
# 4      36.621622          61.299435

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3963 entries, 0 to 3962
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   City               3963 non-null   object
#  1    "Region"          3963 non-null   object
#  2    "Country"         3963 non-null   object
#  3    "AirQuality"      3963 non-null   float64
#  4    "WaterPollution"  3963 non-null   float64
# dtypes: float64(2), object(3)
# memory usage: 154.9+ KB

# %%
columns = ['City', 'Region', 'Country', 'AirQuality', 'WaterPollution']
df.columns = columns
df.head()
# Out:
#                City                   Region                      Country  \
# 0     New York City               "New York"   "United States of America"
# 1  Washington, D.C.   "District of Columbia"   "United States of America"
# 2     San Francisco             "California"   "United States of America"
# 3            Berlin                       ""                    "Germany"
# 4       Los Angeles             "California"   "United States of America"
#
#    AirQuality  WaterPollution
# 0   46.816038       49.504950
# 1   66.129032       49.107143
# 2   60.514019       43.000000
# 3   62.364130       28.612717
# 4   36.621622       61.299435

# %%
df['Region'] = df['Region'].map(lambda x: x.replace('"', ""))
df.head()
# Out:
#                City                 Region                      Country  \
# 0     New York City               New York   "United States of America"
# 1  Washington, D.C.   District of Columbia   "United States of America"
# 2     San Francisco             California   "United States of America"
# 3            Berlin                                           "Germany"
# 4       Los Angeles             California   "United States of America"
#
#    AirQuality  WaterPollution
# 0   46.816038       49.504950
# 1   66.129032       49.107143
# 2   60.514019       43.000000
# 3   62.364130       28.612717
# 4   36.621622       61.299435

# %%
df['Country'] = df['Country'].map(lambda x: x.replace('"', ""))
df.head()
# Out:
#                City                 Region                    Country  \
# 0     New York City               New York   United States of America
# 1  Washington, D.C.   District of Columbia   United States of America
# 2     San Francisco             California   United States of America
# 3            Berlin                                           Germany
# 4       Los Angeles             California   United States of America
#
#    AirQuality  WaterPollution
# 0   46.816038       49.504950
# 1   66.129032       49.107143
# 2   60.514019       43.000000
# 3   62.364130       28.612717
# 4   36.621622       61.299435

# %%
df.to_csv('Updated_dataset.csv', index=False)

# %%
df['Country'] = df['Country'].map(lambda x: x.strip())

# %%
df[df['Country'] == 'Germany']
# Out:
#                         City                   Region  Country  AirQuality  \
# 3                     Berlin                           Germany   62.364130
# 28                   Cologne   North Rhine-Westphalia  Germany   60.714286
# 40                      Bonn   North Rhine-Westphalia  Germany   82.812500
# 52                 Heilbronn        Baden-Wurttemberg  Germany   80.000000
# 76                    Aachen   North Rhine-Westphalia  Germany   70.454545
# ...                      ...                      ...      ...         ...
# 2693             Bad Waldsee        Baden-Wurttemberg  Germany  100.000000
# 2714  Weilheim in Oberbayern                  Bavaria  Germany  100.000000
# 2727                  Buckow              Brandenburg  Germany   87.500000
# 3942                  Erfurt                Thuringia  Germany   85.000000
# 3943  Garmisch-Partenkirchen                  Bavaria  Germany  100.000000
#
#       WaterPollution
# 3          28.612717
# 28         27.777778
# ...

# %%
df[df['Country'] == 'Uzbekistan']
# Out:
#         City Region     Country  AirQuality  WaterPollution
# 21  Tashkent         Uzbekistan   56.451613       49.166667

# %%
df[df['Country'] == 'Tajikistan']
# Out:
#          City Region     Country  AirQuality  WaterPollution
# 535  Dushanbe         Tajikistan   41.666667       61.111111

# %%
df
# Out:
#                   City                 Region                   Country  \
# 0        New York City               New York  United States of America
# 1     Washington, D.C.   District of Columbia  United States of America
# 2        San Francisco             California  United States of America
# 3               Berlin                                          Germany
# 4          Los Angeles             California  United States of America
# ...                ...                    ...                       ...
# 3958             Yanbu        Medina Province              Saudi Arabia
# 3959           Cordoba              Andalusia                     Spain
# 3960               Vic              Catalonia                     Spain
# 3961           Segovia       Castile and Leon                     Spain
# 3962       Zamora city       Castile and Leon                     Spain
#
#       AirQuality  WaterPollution
# 0      46.816038       49.504950
# 1      66.129032       49.107143
# ...

# %%
df.Country.unique()
# Out:
# array(['United States of America', 'Germany', 'Switzerland',
#        'United Kingdom', 'Egypt', 'France', 'Canada', 'Brazil',
#        'Lithuania', 'Monaco', 'Belgium', 'Poland', 'Uzbekistan', 'Italy',
#        'Singapore', 'North Macedonia', 'Slovenia', 'Bulgaria', 'Norway',
#        'Portugal', 'United Arab Emirates', 'Russia',
#        "People's Republic of China", 'Georgia', 'India', 'Czech Republic',
#        'Israel', 'Uruguay', 'Bangladesh', 'Pakistan', 'Croatia',
#        'Philippines', 'Argentina', 'Mexico', 'Japan', 'Bolivia', 'Spain',
#        "Cote d'Ivoire", 'Greece', 'Venezuela', 'Guatemala', 'Cuba',
#        'Austria', 'Sweden', 'Finland', 'Ireland', 'Iceland', 'Estonia',
#        'Latvia', 'Slovakia', 'Hungary', 'Luxembourg', 'Liechtenstein',
#        'San Marino', 'Cambodia', 'Vietnam', 'Thailand', 'Andorra',
#        'Malaysia', 'Taiwan', 'Ukraine', 'Chile', 'South Sudan', 'Armenia',
#        'Tanzania', 'Sudan', 'Belarus', 'Somalia', 'The Bahamas', 'Yemen',
# ...

# %% [markdown]
# pivot_table() - metodi yoradamida multi indekslash

# %%
df1 = pd.pivot_table(df, index=['Country', 'City'], aggfunc=lambda x: x)
df1
# Out:
#                      AirQuality                         Region WaterPollution
# Country     City
# Afghanistan Andkhoy        50.0                         Faryab           50.0
#             Farah         100.0                          Farah            0.0
#             Herat         43.75                          Herat          31.25
#             Kabul     18.421053                          Kabul      81.060606
#             Kandahar        0.0                       Kandahar           75.0
# ...                         ...                            ...            ...
# Zambia      Mansa          75.0               Luapula Province           25.0
# Zimbabwe    Bindura        50.0   Mashonaland Central Province           75.0
#             Bulawayo  67.857143                                     71.428571
#             Harare    38.461538                                          87.5
#             Masvingo       25.0                                          62.5
#
# ...

# %%
df1.index
# Out:
# MultiIndex([('Afghanistan',        'Andkhoy'),
#             ('Afghanistan',          'Farah'),
#             ('Afghanistan',          'Herat'),
#             ('Afghanistan',          'Kabul'),
#             ('Afghanistan',       'Kandahar'),
#             ('Afghanistan', 'Mazar-i-Sharif'),
#             (    'Albania',         'Ballsh'),
#             (    'Albania',         'Burrel'),
#             (    'Albania',         'Durres'),
#             (    'Albania',        'Elbasan'),
#             ...
#             (      'Yemen',          'Sanaa'),
#             (      'Yemen',         'Ta'izz'),
#             (     'Zambia',       'Chingola'),
#             (     'Zambia',          'Kitwe'),
#             (     'Zambia',         'Lusaka'),
#             (     'Zambia',          'Mansa'),
#             (   'Zimbabwe',        'Bindura'),
#             (   'Zimbabwe',       'Bulawayo'),
#             (   'Zimbabwe',         'Harare'),
#             (   'Zimbabwe',       'Masvingo')],
# ...

# %%
df1.loc[['Uzbekistan', 'Germany']]
# Out:
#                          AirQuality                   Region WaterPollution
# Country    City
# Uzbekistan Tashkent       56.451613                               49.166667
# Germany    Aachen         70.454545   North Rhine-Westphalia      17.857143
#            Aalen               87.5        Baden-Wurttemberg           50.0
#            Abensberg          100.0                  Bavaria           50.0
#            Amberg             100.0                  Bavaria           50.0
# ...                             ...                      ...            ...
#            Wilhelmshaven      100.0             Lower Saxony           50.0
#            Wolfsburg         96.875             Lower Saxony            0.0
#            Worms               60.0     Rhineland-Palatinate          100.0
#            Wuppertal           90.0   North Rhine-Westphalia            0.0
#            Zwickau             75.0                   Saxony           50.0
#
# [125 rows x 3 columns]

# %%
df2 = df1.copy()

# %%
df2.drop(['Region'], axis=1, inplace=True)

# %%
df2['AirPollution'] = 100 - df2['AirQuality']
df2
# Out:
#                      AirQuality WaterPollution AirPollution
# Country     City
# Afghanistan Andkhoy        50.0           50.0         50.0
#             Farah         100.0          100.0          0.0
#             Herat         43.75          68.75        56.25
#             Kabul     18.421053      18.939394    81.578947
#             Kandahar        0.0           25.0        100.0
# ...                         ...            ...          ...
# Zambia      Mansa          75.0           75.0         25.0
# Zimbabwe    Bindura        50.0           25.0         50.0
#             Bulawayo  67.857143      28.571429    32.142857
#             Harare    38.461538           12.5    61.538462
#             Masvingo       25.0           37.5         75.0
#
# [3895 rows x 3 columns]

# %%
df2['WaterQuality'] = 100 - df2['WaterPollution']
df2
# Out:
#                      AirQuality WaterPollution AirPollution WaterQuality
# Country     City
# Afghanistan Andkhoy        50.0           50.0         50.0         50.0
#             Farah         100.0          100.0          0.0          0.0
#             Herat         43.75          68.75        56.25        31.25
#             Kabul     18.421053      18.939394    81.578947    81.060606
#             Kandahar        0.0           25.0        100.0         75.0
# ...                         ...            ...          ...          ...
# Zambia      Mansa          75.0           75.0         25.0         25.0
# Zimbabwe    Bindura        50.0           25.0         50.0         75.0
#             Bulawayo  67.857143      28.571429    32.142857    71.428571
#             Harare    38.461538           12.5    61.538462         87.5
#             Masvingo       25.0           37.5         75.0         62.5
#
# [3895 rows x 4 columns]

# %%
df3 = pd.DataFrame(df2.values, index=df2.index, columns=[['AIR', 'AIR', 'WATER', 'WATER'], ['AirQuality', 'AirPollution', 'WaterQuality', 'WaterPollution']])
df3
# Out:
#                             AIR                     WATER
#                      AirQuality AirPollution WaterQuality WaterPollution
# Country     City
# Afghanistan Andkhoy        50.0         50.0         50.0           50.0
#             Farah         100.0        100.0          0.0            0.0
#             Herat         43.75        68.75        56.25          31.25
#             Kabul     18.421053    18.939394    81.578947      81.060606
#             Kandahar        0.0         25.0        100.0           75.0
# ...                         ...          ...          ...            ...
# Zambia      Mansa          75.0         75.0         25.0           25.0
# Zimbabwe    Bindura        50.0         25.0         50.0           75.0
#             Bulawayo  67.857143    28.571429    32.142857      71.428571
#             Harare    38.461538         12.5    61.538462           87.5
#             Masvingo       25.0         37.5         75.0           62.5
#
# ...

# %%
df3['AIR']
# Out:
#                      AirQuality AirPollution
# Country     City
# Afghanistan Andkhoy        50.0         50.0
#             Farah         100.0        100.0
#             Herat         43.75        68.75
#             Kabul     18.421053    18.939394
#             Kandahar        0.0         25.0
# ...                         ...          ...
# Zambia      Mansa          75.0         75.0
# Zimbabwe    Bindura        50.0         25.0
#             Bulawayo  67.857143    28.571429
#             Harare    38.461538         12.5
#             Masvingo       25.0         37.5
#
# [3895 rows x 2 columns]

# %%
df3['WATER']
# Out:
#                      WaterQuality WaterPollution
# Country     City
# Afghanistan Andkhoy          50.0           50.0
#             Farah             0.0            0.0
#             Herat           56.25          31.25
#             Kabul       81.578947      81.060606
#             Kandahar        100.0           75.0
# ...                           ...            ...
# Zambia      Mansa            25.0           25.0
# Zimbabwe    Bindura          50.0           75.0
#             Bulawayo    32.142857      71.428571
#             Harare      61.538462           87.5
#             Masvingo         75.0           62.5
#
# [3895 rows x 2 columns]

# %%
df3
# Out:
#                             AIR                     WATER
#                      AirQuality AirPollution WaterQuality WaterPollution
# Country     City
# Afghanistan Andkhoy        50.0         50.0         50.0           50.0
#             Farah         100.0        100.0          0.0            0.0
#             Herat         43.75        68.75        56.25          31.25
#             Kabul     18.421053    18.939394    81.578947      81.060606
#             Kandahar        0.0         25.0        100.0           75.0
# ...                         ...          ...          ...            ...
# Zambia      Mansa          75.0         75.0         25.0           25.0
# Zimbabwe    Bindura        50.0         25.0         50.0           75.0
#             Bulawayo  67.857143    28.571429    32.142857      71.428571
#             Harare    38.461538         12.5    61.538462           87.5
#             Masvingo       25.0         37.5         75.0           62.5
#
# ...

# %%
df3.columns.names = ['Object', 'Info']
df3
# Out:
# Object                      AIR                     WATER
# Info                 AirQuality AirPollution WaterQuality WaterPollution
# Country     City
# Afghanistan Andkhoy        50.0         50.0         50.0           50.0
#             Farah         100.0        100.0          0.0            0.0
#             Herat         43.75        68.75        56.25          31.25
#             Kabul     18.421053    18.939394    81.578947      81.060606
#             Kandahar        0.0         25.0        100.0           75.0
# ...                         ...          ...          ...            ...
# Zambia      Mansa          75.0         75.0         25.0           25.0
# Zimbabwe    Bindura        50.0         25.0         50.0           75.0
#             Bulawayo  67.857143    28.571429    32.142857      71.428571
#             Harare    38.461538         12.5    61.538462           87.5
#             Masvingo       25.0         37.5         75.0           62.5
#
# ...

# %%
df3.index.names
# Out:
# FrozenList(['Country', 'City'])

# %%
df3
# Out:
# Object                      AIR                     WATER
# Info                 AirQuality AirPollution WaterQuality WaterPollution
# Country     City
# Afghanistan Andkhoy        50.0         50.0         50.0           50.0
#             Farah         100.0        100.0          0.0            0.0
#             Herat         43.75        68.75        56.25          31.25
#             Kabul     18.421053    18.939394    81.578947      81.060606
#             Kandahar        0.0         25.0        100.0           75.0
# ...                         ...          ...          ...            ...
# Zambia      Mansa          75.0         75.0         25.0           25.0
# Zimbabwe    Bindura        50.0         25.0         50.0           75.0
#             Bulawayo  67.857143    28.571429    32.142857      71.428571
#             Harare    38.461538         12.5    61.538462           87.5
#             Masvingo       25.0         37.5         75.0           62.5
#
# ...

# %%
df3 = df3.swaplevel('Country', 'City')
df3
# Out:
# Object                      AIR                     WATER
# Info                 AirQuality AirPollution WaterQuality WaterPollution
# Country     City
# Afghanistan Andkhoy        50.0         50.0         50.0           50.0
#             Farah         100.0        100.0          0.0            0.0
#             Herat         43.75        68.75        56.25          31.25
#             Kabul     18.421053    18.939394    81.578947      81.060606
#             Kandahar        0.0         25.0        100.0           75.0
# ...                         ...          ...          ...            ...
# Zambia      Mansa          75.0         75.0         25.0           25.0
# Zimbabwe    Bindura        50.0         25.0         50.0           75.0
#             Bulawayo  67.857143    28.571429    32.142857      71.428571
#             Harare    38.461538         12.5    61.538462           87.5
#             Masvingo       25.0         37.5         75.0           62.5
#
# ...

# %%
#df3.swaplevel(0, 1)

# %% [markdown]
# sort_index() - metodidan foydalanish

# %%
df3.sort_index(level=0, ascending=False)
# Out:
# Object                      AIR                     WATER
# Info                 AirQuality AirPollution WaterQuality WaterPollution
# Country     City
# Zimbabwe    Masvingo       25.0         37.5         75.0           62.5
#             Harare    38.461538         12.5    61.538462           87.5
#             Bulawayo  67.857143    28.571429    32.142857      71.428571
#             Bindura        50.0         25.0         50.0           75.0
# Zambia      Mansa          75.0         75.0         25.0           25.0
# ...                         ...          ...          ...            ...
# Afghanistan Kandahar        0.0         25.0        100.0           75.0
#             Kabul     18.421053    18.939394    81.578947      81.060606
#             Herat         43.75        68.75        56.25          31.25
#             Farah         100.0        100.0          0.0            0.0
#             Andkhoy        50.0         50.0         50.0           50.0
#
# ...
